# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rc('font', family='NanumBarunGothic')
plt.rcParams['axes.unicode_minus']=False
data = pd.read_csv("C:/djangogirls/data/3dieases_People.csv",engine="python")
data.head()
# Out:
#    성별코드  연령대코드(5세단위)  허리둘레  시력(좌)  시력(우)  수축기혈압  이완기혈압  식전혈당(공복혈당)  총콜레스테롤  \
# 0     2           13    57      0      0    130     70         101     220
# 1     2           15    61      0      0    142     79         123     168
# 2     2           11    61      0      0    131     77         109     203
# 3     2            7    62      0      0    128     89         104     148
# 4     2           16    63      0      0     96     64         102     190
#
#    트리글리세라이드     ...      고혈압위험도(이완)      zy1      zy2     zy3      zy4  \
# 0       153     ...         -45.750  193.048   86.683  62.458  112.904
# 1        88     ...         -97.752  189.048   89.949  64.597  106.146
# 2       174     ...         -85.797  189.598   81.773  66.038  106.965
# 3       168     ...         -94.786  196.635  100.934  67.292  109.019
# 4       162     ...         -73.150  189.389   80.809  61.660  111.153
#
#    이상지질혈증 위험도(총콜)  이상지질혈증 위험도(트리)  이상지질혈증 위험도(HDL)  이상지질혈증 위험도(LDL)  \
# ...

# %%
data1 = data.iloc[:,-5:]
print(data1)
# Out:
#        이상지질혈증 위험도(총콜)  이상지질혈증 위험도(트리)  이상지질혈증 위험도(HDL)  이상지질혈증 위험도(LDL)  \
# 0             -17.381        -126.634          -12.288           21.506
# 1             -27.380        -120.103          -22.987           10.243
# 2             -26.006        -136.455          -30.191           11.608
# 3              -8.413         -98.131          -36.458           15.031
# 4             -26.528        -138.382           -8.298           18.589
# 5              -7.266        -117.881           -8.949           27.831
# 6             -18.182        -123.156          -21.145           17.529
# 7              -9.833        -101.720           -9.473           23.289
# 8             -39.317        -155.776          -13.229           11.578
# 9              -9.010        -113.246          -17.276           23.266
# 10            -19.419        -117.384          -21.760           15.631
# 11             -4.837        -101.074          -16.769           24.264
# ...

# %%
print(data1['이상지질혈증 위험도(총콜)'][0])
print(data1['이상지질혈증 위험도(트리)'][0])
print(data1['이상지질혈증 위험도(HDL)'][0])
print(data1['이상지질혈증 위험도(LDL)'][0])
print(data1['이상지질혈증 위험도'][0])
# Out:
# -17.381
# -120.103
# -30.191
# 15.030999999999999
# 18.589000000000002
